# %% [markdown]
# <a href="https://colab.research.google.com/github/Arias0907/filtros-paso-alto-y-bajo/blob/master/Fourier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Fourier**

# %%
from google.colab import drive
drive.mount('/content/drive')



import numpy as np
import matplotlib.pyplot as plt
import cv2
import os

path='/content/drive/My Drive/PDI/Ejemplos Clase/'
os.chdir(path)
# !pwd
# graficar imagenes estaticas en el notebook

# %matplotlib inline
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# /content/drive/My Drive/PDI/Ejemplos Clase

# %%
def displayGray3(a,b,c, title1 = "Original", title2 = "Edited", title3 = "Edited"):
    plt.figure(figsize=(12,4))
    plt.subplot(131), plt.imshow(a, cmap='gray'), plt.title(title1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(132), plt.imshow(b, cmap='gray'), plt.title(title2)
    plt.xticks([]), plt.yticks([])
    plt.subplot(133), plt.imshow(c, cmap = 'gray'), plt.title(title3)
    plt.xticks([]), plt.yticks([])
    plt.show()
    
def displayGray2(a,b, title1 = "Original", title2 = "Edited"):
    plt.figure(figsize=(12,12))
    plt.subplot(121), plt.imshow(a, cmap='gray'), plt.title(title1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(122), plt.imshow(b, cmap='gray'), plt.title(title2)
    plt.xticks([]), plt.yticks([])
    plt.show()
    
def displayColor3(a,b,c, title1 = "Original", title2 = "Edited", title3 = "Edited"):
    plt.figure(figsize=(10,10))
    plt.subplot(131), plt.imshow(a), plt.title(title1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(132), plt.imshow(b), plt.title(title2)
    plt.xticks([]), plt.yticks([])
    plt.subplot(133), plt.imshow(c), plt.title(title3)
    plt.xticks([]), plt.yticks([])
    plt.show()
    
def displayColor2(a,b, title1 = "Original", title2 = "Edited"):
    plt.figure(figsize=(15,15))
    plt.subplot(131), plt.imshow(a), plt.title(title1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(132), plt.imshow(b), plt.title(title2)
    plt.xticks([]), plt.yticks([])
    plt.show()
    
def readRGB(imgPath):
    img = cv2.imread(imgPath)
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    return img

# %%
img = cv2.imread('49.jpg', 0)
f = np.fft.fft2(img)
fshift = np.fft.fftshift(f)
magnitude_spectrum = 20*np.log(np.abs(fshift))

displayGray2(img, magnitude_spectrum, "Input Image", "Magnitude Spectrum")

img1 = cv2.imread('a1.png', 0)
f1 = np.fft.fft2(img1)
fshift1 = np.fft.fftshift(f1)
magnitude_spectrum1 = 20*np.log(np.abs(fshift1))

displayGray2(img1, magnitude_spectrum1, "Input Image", "Magnitude Spectrum")

img2= cv2.imread('S.png', 0)
f2 = np.fft.fft2(img2)
fshift2 = np.fft.fftshift(f2)
magnitude_spectrum2 = 20*np.log(np.abs(fshift2))

displayGray2(img2, magnitude_spectrum2, "Input Image", "Magnitude Spectrum")


img3 = cv2.imread('S1.png', 0)
f3 = np.fft.fft2(img3)
fshift3 = np.fft.fftshift(f3)
magnitude_spectrum3 = 20*np.log(np.abs(fshift3))

displayGray2(img3, magnitude_spectrum3, "Input Image", "Magnitude Spectrum")

img4 = cv2.imread('K.png', 0)
f4 = np.fft.fft2(img4)
fshift4 = np.fft.fftshift(f4)
magnitude_spectrum4 = 20*np.log(np.abs(fshift4))

displayGray2(img4, magnitude_spectrum4, "Input Image", "Magnitude Spectrum")

img5 = cv2.imread('K1.png', 0)
f5 = np.fft.fft2(img5)
fshift5 = np.fft.fftshift(f5)
magnitude_spectrum5 = 20*np.log(np.abs(fshift5))

displayGray2(img5, magnitude_spectrum5, "Input Image", "Magnitude Spectrum")

# %%
f = np.fft.fft2(img)
fshift = np.fft.fftshift(f)
magnitude_spectrum_c = 20*np.log(np.abs(fshift))
magnitude_spectrum_ori = 20*np.log(np.abs(f))

displayGray3(img, magnitude_spectrum_c, magnitude_spectrum_ori, "Original", "Spectro centrado", "Spectro sin centrar")

f1 = np.fft.fft2(img1)
fshift1 = np.fft.fftshift(f1)
magnitude_spectrum_c1 = 20*np.log(np.abs(fshift1))
magnitude_spectrum_ori1 = 20*np.log(np.abs(f1))

displayGray3(img1, magnitude_spectrum_c1, magnitude_spectrum_ori1, "Original", "Spectro centrado", "Spectro sin centrar")

# %% [markdown]
# #**Filtro pasa bajas**

# %%
img = cv2.imread('47.jpg', 0)
img_flotante = np.float32(img)
dft = cv2.dft(img_flotante, flags = cv2.DFT_COMPLEX_OUTPUT)
dft_shift=np.fft.fftshift(dft)
magnitude_spectrum = 20*np.log(cv2.magnitude(dft_shift[:,:,0], dft_shift[:,:,1]))
fils, cols = img.shape
centfils, centcols = fils/2, cols/2

#creemos unas mascara con un centro cuadrado de 1 y el resto zeros
mask = np.zeros((fils, cols, 2), np.uint8)
mask[np.int32(centfils)-15:np.int32(centfils)+15, np.int32(centcols)-15:np.int32(centcols)+15]=1

##Aplicquemos la mascara y luego obtenemos la inversa de DFT
fshift = dft_shift*mask
fshift_mask_mag = 2000* np.log(cv2.magnitude(fshift[:,:,0], fshift[:,:,1]))

f_shift = np.fft.ifftshift(fshift)
img_back = cv2.idft(f_shift)
img_back = cv2.magnitude(img_back[:,:,0], img_back[:,:,1])

displayGray2(img, img_back)
displayGray2(fshift_mask_mag, magnitude_spectrum)

# %% [markdown]
# #**Filtro pasa altas**

# %%
img = cv2.imread('47.jpg', 0)
img_flotante = np.float32(img)
dft = cv2.dft(img_flotante, flags = cv2.DFT_COMPLEX_OUTPUT)
dft_shift=np.fft.fftshift(dft)
magnitude_spectrum = 20*np.log(cv2.magnitude(dft_shift[:,:,0], dft_shift[:,:,1]))
fils, cols = img.shape
centfils, centcols = fils/2, cols/2

#creemos unas mascara con un centro cuadrado de 1 y el resto zeros
mask = np.ones((fils, cols, 2), np.uint8)
mask[np.int32(centfils)-50:np.int32(centfils)+50, np.int32(centcols)-50:np.int32(centcols)+50]=0

##Aplicquemos la mascara y luego obtenemos la inversa de DFT
fshift = dft_shift*mask
fshift_mask_mag = 2000* np.log(cv2.magnitude(fshift[:,:,0], fshift[:,:,1]))

f_shift = np.fft.ifftshift(fshift)
img_back = cv2.idft(f_shift)
img_back = cv2.magnitude(img_back[:,:,1], img_back[:,:,0])

displayGray2(img, img_back)
displayGray2(fshift_mask_mag, magnitude_spectrum)

# %% [markdown]
# #**Filtro pasa altas mascara en forma de circunferencia**

# %%
img = cv2.imread('47.jpg', 0)
img_flotante = np.float32(img)
dft = cv2.dft(img_flotante, flags = cv2.DFT_COMPLEX_OUTPUT)
dft_shift=np.fft.fftshift(dft)
magnitude_spectrum = 20*np.log(cv2.magnitude(dft_shift[:,:,0], dft_shift[:,:,1]))
fils, cols = img.shape
centfils, centcols = fils/2, cols/2

#creemos unas mascara con un centro cuadrado de 1 y el resto zeros
mask = np.ones((fils, cols, 2), np.uint8)
r = 30
center = [centfils, centcols]
x, y = np.ogrid[:fils, :cols]

mask = np.ones((fils, cols, 2), np.uint8)
mask_area = (x - center[0])**2 + (y - center[1])**2 <= r*r
mask[mask_area] = 0

##Aplicquemos la mascara y luego obtenemos la inversa de DFT
fshift = dft_shift*mask
fshift_mask_mag = 2000* np.log(cv2.magnitude(fshift[:,:,0], fshift[:,:,1]))

f_shift = np.fft.ifftshift(fshift)
img_back = cv2.idft(f_shift)
img_back = cv2.magnitude(img_back[:,:,1], img_back[:,:,0])

displayGray2(img, img_back)
displayGray2(fshift_mask_mag, magnitude_spectrum)

# %% [markdown]
# #**Filtro pasa bajas mascara en forma de circunferencia**

# %%
img = cv2.imread('nasa.png', 0)
img_flotante = np.float32(img)
dft = cv2.dft(img_flotante, flags = cv2.DFT_COMPLEX_OUTPUT)
dft_shift=np.fft.fftshift(dft)
magnitude_spectrum = 20*np.log(cv2.magnitude(dft_shift[:,:,0], dft_shift[:,:,1]))
fils, cols = img.shape
centfils, centcols = fils/2, cols/2

#creemos unas mascara con un centro cuadrado de 1 y el resto zeros
mask = np.zeros((fils, cols, 2), np.uint8)
r = 50
center = [centfils, centcols]
x, y = np.ogrid[:fils, :cols]

mask = np.zeros((fils, cols, 2), np.uint8)
mask_area = (x - center[0])**2 + (y - center[1])**2 <= r*r
mask[mask_area] = 1

##Aplicquemos la mascara y luego obtenemos la inversa de DFT
fshift = dft_shift*mask
fshift_mask_mag = 2000* np.log(cv2.magnitude(fshift[:,:,0], fshift[:,:,1]))

f_shift = np.fft.ifftshift(fshift)
img_back = cv2.idft(f_shift)
img_back = cv2.magnitude(img_back[:,:,1], img_back[:,:,0])

displayGray2(img, img_back)
displayGray2(fshift_mask_mag, magnitude_spectrum)

# %% [markdown]
# #**Filtros bilateral, sharpened, y median blur**

# %%
img = cv2.imread("saltlgle.png", 0)

median = cv2.medianBlur(img, 5)
kernel_sharpening = np.array([[-1, -1, -1], [-1, 9, -1], [-1, -1, -1]])

sharpened = cv2.filter2D(median, -1, kernel_sharpening)
bilateral = cv2.bilateralFilter(sharpened, 9, 75, 75)

displayGray2(img, median)
displayGray3(median, sharpened, bilateral)

img = cv2.imread("saltpepper.png", 0)

median = cv2.medianBlur(img, 5)
median1 = cv2.medianBlur(median, 5)
median2 = cv2.medianBlur(median1, 5)
median3 = cv2.medianBlur(median2, 5)
median4 = cv2.medianBlur(median3, 5)
bilateral = cv2.bilateralFilter(median4, 9, 75, 75)

displayGray3(img, median4, bilateral)

# %% [markdown]
# #**Bilateral**

# %%
img = cv2.imread("saltpepper.png",0)

bilateral = cv2.bilateralFilter(img, 9, 75, 75)

displayGray2 (img, bilateral)

# %% [markdown]
# #**Blur Laplaciano**

# %%
img = cv2.imread("saltlgle.png", 0)
median = cv2.medianBlur(img, 5)
lapl = cv2.Laplacian(median, cv2.CV_64F, ksize=5)

displayGray2(median, lapl)

# %% [markdown]
# #**Laplacianos diferentes de la clase**

# %%
#primer laplaciano de la clase
img = cv2.imread("saltlgle.png",0)

median = cv2.medianBlur(img, 5)

bilateral = cv2.bilateralFilter(img, 9, 75, 75)

kernel_laplaciano = np.array([[0, 1, 0], [1, -4, 1], [0, 1, 0]])

sharpened = cv2.filter2D(median, -1, kernel_laplaciano)

displayGray2(median, sharpened)

#segundo laplaciano de la clase

kernel_laplaciano1 = np.array([[0, -1, 0], [-1, 4, -1], [0, -1, 0]])

sharpened1 = cv2.filter2D(median, -1, kernel_laplaciano1)

displayGray2(median, sharpened1)

#tercer laplaciano de la clase

kernel_laplaciano2 = np.array([[-1, -1, -1], [-1, 8, -1], [-1, -1, -1]])

sharpened2 = cv2.filter2D(median, -1, kernel_laplaciano2)

displayGray2(median, sharpened2)

#cuarto laplaciano de la clase

kernel_laplaciano3 = np.array([[1, 1, 1], [1, -8, 1], [1, 1, 1]])

sharpened3 = cv2.filter2D(median, -1, kernel_laplaciano3)

displayGray2(median, sharpened3)

#quinto laplaciano de la clase

kernel_laplaciano4 = np.array([[1, 0, -1], [2, 0, -2], [1, 0, -1]])

sharpened4 = cv2.filter2D(median, -1, kernel_laplaciano4)

displayGray2(median, sharpened4)

#sexto laplaciano de la clase

kernel_laplaciano5 = np.array([[1, 2, 1], [0, 0, 0], [-1, -2, -1]])

sharpened5 = cv2.filter2D(median, -1, kernel_laplaciano5)

displayGray2(median, sharpened5)

# %% [markdown]
# #**Derivada en x**

# %%
img = cv2.imread('furi2.jpg', 0)

x_sobel = cv2.Sobel(img, cv2.CV_64F, 1, 0, ksize=5)

displayGray2(img, x_sobel)

# %% [markdown]
# #**Derivada en y**

# %%
img = cv2.imread('furi2.jpg', 0)

y_sobel = cv2.Sobel(img, cv2.CV_64F, 0, 1, ksize=5)

displayGray2(img, y_sobel)

# %% [markdown]
# #**Suma de las derivadas**

# %%
sobel = x_sobel + y_sobel

displayGray2(img, sobel)

# %%
img = cv2.imread('furi2.jpg', 0)


kernel_laplaciano1 = np.array([[-1, 0, 1], [-2, 0, 2], [-1, 0, 1]])

x_sobel = cv2.filter2D(img, -1, kernel_laplaciano1)

displayGray2(img, x_sobel)

#tercer laplaciano de la clase

kernel_laplaciano2 = np.array([[-1, -2, -1], [0, 0, 0], [1, 2, 1]])

y_sobel = cv2.filter2D(img, -1, kernel_laplaciano2)

sobel = x_sobel + y_sobel

displayGray2(y_sobel, sobel)
